# %% [markdown]
# ## Convert string text to a words list

# %%
import pandas as pd
from natto import MeCab

# %%
review_df = pd.read_csv("data/523_reviews_df.csv")

# %%
def txt2words(txt):
    posid = [36,37,38,40,41,42,43,44,45,46,47,50,51,52,66,67,2,31,36,10,34]
    words = []
    parser = MeCab()
    nodes = parser.parse(txt,as_nodes=True)
    for node in nodes:
        if not node.is_eos():
            feature = node.feature.split(',')
            if node.posid in posid and feature[6] != "*":
                words.append(feature[6]) 
    return words

# %%
words = txt2words(review_df.reviews[0])

# %%
words
# Out:
# ['正直',
#  '目',
#  'アナ',
#  '雪',
#  '好き',
#  'ない',
#  'もちろん',
#  '音楽',
#  '映像',
#  '素晴らしい',
#  'キャラクター',
#  '魅力',
#  '的',
#  '奮闘',
#  'する',
#  '結局',
#  '姉妹',
#  '愛',
#  'どうにも',
#  '納得',
#  'できる',
#  '言う',
#  '自分',
#  '人',
#  '大切',
#  '思う',
#  '真実',
#  '愛',
#  'する',
#  'アナ',
#  'ため',
#  '溶ける',
#  'いう',
#  '究極',
#  '愛',
#  'アナ',
#  'ため',
#  '身',
#  '引く',
#  'やはり',
#  '真実',
#  '愛',
#  '示す',
#  'アナ',
#  '氷',
#  '溶かす',
#  'できる',
#  'ずっと',
#  '疑問',
#  '先日',
#  'テレビ',
#  '放送',
#  '観る',
#  'ようやく',
#  '気付く',
#  'アナ',
#  '氷',
#  '溶かす',
#  'アナ',
#  '凍る',
#  '心',
#  '溶かす',
#  'アナ',
#  '愛す',
#  '重要',
#  'アナ',
#  '助け',
#  '求める',
#  'ハンス',
#  '殺す',
#  '身',
#  '挺',
#  'する',
#  '庇う',
#  '自分',
#  '人',
#  '大切',
#  '思う',
#  '真実',
#  '愛',
#  '与える',
#  '凍る',
#  '心',
#  '溶ける',
#  'アナ',
#  'かける',
#  '氷',
#  '魔法',
#  '解ける',
#  '前作',
#  'アナ',
#  '心',
#  '成長',
#  '描く',
#  '映画',
#  'アナ',
#  '救う',
#  '物語',
#  '本人',
#  '描く',
#  '足りる',
#  '思う',
#  '意味',
#  '続編',
#  '作る',
#  '作品',
#  '言える',
#  '今',
#  '作',
#  '早々',
#  '公開',
#  'する',
#  'リード',
#  '曲',
#  '歌う',
#  '魔法',
#  '秘密',
#  '解き明かす',
#  'ため',
#  'アナ',
#  '冒険',
#  '出る',
#  '物語',
#  'もちろん',
#  'いる',
#  '全面',
#  'サポート',
#  'する',
#  '目',
#  '違う',
#  'アナ',
#  '困難',
#  '立ち向かう',
#  '姿',
#  '描く',
#  'もはや',
#  'プリンセス',
#  'いう',
#  '国民',
#  '背負う',
#  '王',
#  '言う',
#  'いう',
#  '今年',
#  '公開',
#  'する',
#  'アラジン',
#  'オリジナル',
#  'ない',
#  'ジャスミン',
#  '歌',
#  '追加',
#  'する',
#  '昨今',
#  'もてはやす',
#  'フェミニズム',
#  '合わせる',
#  '確か',
#  'ジャスミン',
#  '結婚',
#  'する',
#  'アラジン',
#  '一国',
#  '王',
#  'なれる',
#  '考える',
#  '難しい',
#  '自ら',
#  '立ち上がり',
#  '国',
#  '背負う',
#  '冒険',
#  '繰り出す',
#  '国',
#  'リーダー',
#  'なる',
#  'もう',
#  '男',
#  '特権',
#  '責務',
#  'なくなる',
#  'いう',
#  '女性',
#  'いう',
#  'ない',
#  'アナ',
#  'ピンチ',
#  'とき',
#  '共に',
#  '困難',
#  '立ち向かう',
#  '女',
#  '男',
#  'いう',
#  'キャラクター',
#  '個人',
#  '個人',
#  '自身',
#  'やる',
#  '役割',
#  '果たす',
#  'する',
#  '人間',
#  'ない',
#  '様々',
#  '場面',
#  '活躍',
#  'する',
#  'まさに',
#  '目',
#  '自分',
#  '感情',
#  '押しつけ',
#  'がち',
#  'アナ',
#  '天真爛漫',
#  'ある',
#  'きちんと',
#  '大人',
#  '女性',
#  '成長',
#  'する',
#  '目',
#  '悩む',
#  '苦しむ',
#  '表情',
#  '多い',
#  '今',
#  '作',
#  '感情',
#  '見せる',
#  '圧巻',
#  '歌',
#  '鳥肌',
#  '立つ',
#  '歌',
#  'ミュージカル',
#  '演出',
#  '笑い',
#  '誘う',
#  '恋する',
#  '男',
#  'いう',
#  '笑わせる',
#  '泣かせる',
#  '活躍',
#  '個人',
#  '的',
#  '声',
#  '演じる',
#  '俳優',
#  '声優',
#  '関係',
#  'ない',
#  '思う',
#  'ピエール',
#  '瀧',
#  '変わる',
#  '感じる',
#  '武内',
#  '駿',
#  '声優',
#  '本領',
#  '発揮',
#  '見せつける',
#  '自然',
#  '共存',
#  '男女',
#  '役割',
#  '現代',
#  '的',
#  '問題',
#  '描く',
#  '最後',
#  'これぞ',
#  'ディズニー',
#  '終わる',
#  'やはり',
#  'ディズニー',
#  'かく',
#  'ある',
#  '追記',
#  'ネタバ',
#  'レ',
#  'あり',
#  'ストーリー',
#  '批判',
#  'ある',
#  '補足',
#  '加える',
#  '上述',
#  'する',
#  '今',
#  '作',
#  '魔法',
#  '力',
#  '秘密',
#  '知る',
#  'ため',
#  '冒険',
#  '人',
#  '幸せ',
#  '変化',
#  '恐れる',
#  'ずっと',
#  '変わる',
#  '不可能',
#  '年々',
#  '日々',
#  '変わる',
#  '向き合う',
#  '自分',
#  '何者',
#  '知る',
#  '冒険',
#  '行く',
#  '決意',
#  'する',
#  '行く',
#  'する',
#  'しっかり',
#  'する',
#  '意見',
#  '言える',
#  'アナ',
#  '成長',
#  '眩しい',
#  '王子',
#  '父',
#  '民',
#  '母',
#  'もと',
#  '生まれる',
#  'アナ',
#  '国',
#  '争う',
#  '原因',
#  '結局',
#  '王',
#  '祖父',
#  '謀略',
#  '悪人',
#  '主人公',
#  '側',
#  '人間',
#  '精霊',
#  '力',
#  '引き継ぐ',
#  '王女',
#  'アナ',
#  '架け橋',
#  'なる',
#  '架け橋',
#  'たもと',
#  'アナ',
#  '対等',
#  '国',
#  '支える',
#  '人々',
#  '魔法',
#  '力',
#  '共存',
#  'する',
#  '魔法',
#  '力',
#  '水',
#  '火',
#  '風',
#  '大地',
#  '自然',
#  'そのもの',
#  'つまり',
#  '人',
#  '自然',
#  '支配',
#  'する',
#  '自然',
#  '共存',
#  'する',
#  '描く',
#  '思える',
#  '自然',
#  '蔑ろ',
#  'する',
#  '過去',
#  '反省',
#  'する',
#  '共存',
#  '共生',
#  'する',
#  'ディズニー',
#  '側',
#  'メッセージ',
#  '津波',
#  '水',
#  '襲撃',
#  '救う',
#  'あたり',
#  '欧米',
#  '都合',
#  '感',
#  '垣間見る',
#  '要するに',
#  'ディズニー',
#  '版',
#  '姫',
#  '言う',
#  'いう',
#  'しれる',
#  'サン',
#  '森',
#  'アシ',
#  'タカ',
#  'タタラ',
#  '場',
#  '暮らす',
#  'ラスト',
#  'アナ',
#  '国',
#  '王',
#  '自然',
#  '人々',
#  '結ぶ',
#  '支える',
#  '字幕',
#  '鑑賞',
#  '前作',
#  '購入',
#  'する',
#  '観る',
#  '大好き',
#  '作品',
#  'ほぼ',
#  '製作',
#  '者',
#  'キャスト',
#  '続投',
#  '世界',
#  '観',
#  '深める',
#  '作品',
#  'なる',
#  '北欧',
#  '神話',
#  '気候',
#  '特徴',
#  '絡める',
#  'キャラクター',
#  '背景',
#  '心理',
#  'きちんと',
#  '描写',
#  'する',
#  '前作',
#  '世界',
#  '観',
#  '広げる',
#  '話',
#  'なる',
#  '圧倒',
#  'する',
#  '全て',
#  '付け',
#  'すごい',
#  '説得',
#  '力',
#  'ある',
#  'すごい',
#  '感銘',
#  '受ける',
#  '主人公',
#  '姉妹',
#  '描写',
#  '前作',
#  '比べる',
#  '大人',
#  '描く',
#  '前作',
#  'アイデンティティ',
#  '開花',
#  '愛する',
#  '意味',
#  '思春期',
#  '悩み',
#  '抱える',
#  '自分',
#  '存在',
#  '意義',
#  '悩む',
#  '厨',
#  '病的',
#  '自暴自棄',
#  'なる',
#  '歌う',
#  '王国',
#  '逃げ出す',
#  'アナ',
#  '愛',
#  '恋',
#  '子ども',
#  '大人',
#  '成長',
#  'する',
#  '女の子',
#  '心理',
#  '全面',
#  '出る',
#  '自分',
#  '意志',
#  'まま',
#  '行動',
#  'する',
#  '前作',
#  '姉妹',
#  '未熟',
#  '初々しい',
#  '経験',
#  'する',
#  'ある',
#  '思春期',
#  '悩み',
#  '持つ',
#  'ヒット',
#  'する',
#  '要員',
#  '美しい',
#  '映像',
#  '音楽',
#  'ほか',
#  'キャラクター',
#  '共感',
#  'できる',
#  'ところ',
#  '多い',
#  '思う',
#  '一転',
#  'する',
#  '本',
#  '作',
#  '大人',
#  '悩み',
#  '持つ',
#  '冒険',
#  'する',
#  '思春期',
#  '自分勝手',
#  '人',
#  '環境',
#  '考える',
#  '行動',
#  'する',
#  '自分',
#  'やる',
#  '自分',
#  '置く',
#  '立場',
#  '使命',
#  'わかる',
#  '上',
#  '役割',
#  '果たす',
#  'する',
#  '愛',
#  '理解',
#  'する',
#  '相手',
#  '尊重',
#  'する',
#  '自分',
#  '大事',
#  'できる',
#  '近代',
#  '的',
#  '考え方',
#  '今',
#  '作',
#  'もはや',
#  'おとぎ話',
#  '女性',
#  '社会',
#  '進出',
#  '伴う',
#  '現代',
#  '女性',
#  '求める',
#  '勇気',
#  '決断',
#  '配慮',
#  '描く',
#  '王妃',
#  '使命',
#  '全う',
#  'する',
#  '王国',
#  '栄える',
#  '自分',
#  '求める',
#  '察知',
#  'する',
#  '周り',
#  '期待',
#  '誠意',
#  '持つ',
#  '応える',
#  '立派',
#  '社会',
#  '人',
#  '中',
#  'もっと',
#  '高い',
#  'スキル',
#  'ある',
#  '心',
#  '底',
#  '楽しむ',
#  '実力',
#  '遺憾無く',
#  '発揮',
#  '出来る',
#  '場所',
#  '他',
#  'ある',
#  'あ',
#  '転職',
#  'キャリア',
#  'アップ',
#  '力',
#  '解放す',
#  '生き生き',
#  '進む',
#  '洞窟',
#  'シーン',
#  '華々しい',
#  '中',
#  '歌詞',
#  '今',
#  '作',
#  '洞窟',
#  '歌',
#  '出る',
#  'する',
#  '前',
#  '投げやり',
#  '感じ',
#  '自分',
#  '強い',
#  '意志',
#  '持つ',
#  '歌う',
#  'ずっと',
#  '悩む',
#  'まま',
#  '下がり',
#  '眉',
#  'キャラ',
#  '生き生き',
#  '過ごせる',
#  '場所',
#  '見つかる',
#  'アナ',
#  '前作',
#  'まま',
#  'お姫様',
#  '今',
#  '作',
#  '人達',
#  '寄り添う',
#  '大人',
#  'なる',
#  '関係',
#  '王国',
#  '内外',
#  '人達',
#  '絆',
#  '強い',
#  '結びつける',
#  '役目',
#  '自ら',
#  '果たす',
#  'いつも',
#  '懸命',
#  'なる',
#  '行動',
#  'する',
#  '女性',
#  '気遣い',
#  '配慮',
#  '職場',
#  'ものすごい',
#  '助かる',
#  '将来',
#  '有望',
#  '管理',
#  '職',
#  '終盤',
#  'どん底',
#  '沈む',
#  '後',
#  '正しい',
#  '判断',
#  'する',
#  'アナ',
#  'ヒロイン',
#  'いう',
#  'ヒーロー',
#  'めちゃくちゃ',
#  'かっこよい',
#  '正直',
#  '前作',
#  'アナ',
#  'っ子',
#  '可愛い',
#  '共感',
#  'できる',
#  '感じ',
#  '今',
#  '作',
#  'ほんとに',
#  '主人公',
#  '感じ',
#  'あ',
#  'いう',
#  '今',
#  '作',
#  'いる',
#  'ヒロイン',
#  '作品',
#  'ほとんど',
#  'プロポーズ',
#  '考える',
#  '周り',
#  'どんなに',
#  '大変',
#  '状況',
#  '揺るぐ',
#  'ついに',
#  '大々的',
#  '歌',
#  '歌う',
#  '迷子',
#  'アナ',
#  '次第',
#  'アナ',
#  'いく',
#  'おいおい',
#  'ギャグ',
#  'パート',
#  '昔',
#  'ディズニー',
#  'プリンセス',
#  'いつか',
#  '王子',
#  '結婚',
#  'する',
#  '幸せ',
#  'なる',
#  '盛大',
#  'スる',
#  'ただ',
#  'ギャグ',
#  '分かる',
#  '堂々',
#  'シーン',
#  '展開',
#  'する',
#  '呆気',
#  '取る',
#  '昔',
#  'おとぎ話',
#  '皮肉る',
#  '思う',
#  '他',
#  '映像',
#  '素晴らしい',
#  '神話',
#  '生物',
#  '描く',
#  '美しい',
#  '音楽',
#  '秀逸',
#  '親',
#  '愛',
#  '色々',
#  '書く',
#  'ある',
#  '割愛',
#  'する',
#  'ぜんぶ',
#  '素晴らしい',
#  '今',
#  '作',
#  '現代',
#  '社会',
#  '生きる',
#  '女性',
#  '陣',
#  'エール',
#  '思う',
#  '一見',
#  '平等',
#  '見える',
#  '社会',
#  '先駆',
#  '者',
#  'なる',
#  '女性',
#  '労働',
#  '者',
#  '数々',
#  '困難',
#  '理不尽',
#  '強いる',
#  '自分',
#  '周り',
#  '尊重',
#  'する',
#  '自分',
#  '生き生き',
#  '働ける',
#  '環境',
#  '選ぶ',
#  '自分',
#  '自身',
#  'まわり',
#  '成長',
#  'する',
#  '発展',
#  'する',
#  'いつも',
#  '周り',
#  '感謝',
#  '愛',
#  '持つ',
#  'ディズニー',
#  'ストーリー',
#  '性',
#  '落ち目',
#  '感じる',
#  '中身',
#  'ない',
#  'ない',
#  'ない',
#  'ない',
#  '差別',
#  '良い',
#  '愛',
#  '大事',
#  '煎じる',
#  '話',
#  '伝える',
#  '上手',
#  '愛',
#  '大事',
#  '前作',
#  'やる',
#  '差別',
#  '良い',
#  '前作',
#  '貿易',
#  '先',
#  '人',
#  '先入観',
#  '敵',
#  'みなす',
#  '間違う',
#  '十分',
#  '伝わる',
#  'いう',
#  'なんで',
#  '死ぬ',
#  '叔父',
#  'する',
#  '尻拭い',
#  'する',
#  '見える',
#  '結果',
#  'やる',
#  '平坦',
#  '緊張',
#  '緩和',
#  'なる',
#  '力',
#  '汎用',
#  '性',
#  '高',
#  '結局',
#  'ご都合主義',
#  '見える',
#  '前作',
#  '力',
#  '完結',
#  'する',
#  '治療',
#  'する',
#  '受け入れる',
#  'する',
#  '綺麗',
#  'まとまる',
#  '何で',
#  '力',
#  '手',
#  '入れる',
#  '前作',
#  'やる',
#  'かなん',
#  '手',
#  '入れる',
#  '含める',
#  '全体',
#  '的',
#  'ストーリー',
#  '読む',
#  'エン',
#  'タメ',
#  '性',
#  '欠ける',
#  '純粋',
#  '楽しい',
#  'ミュージカル',
#  'シーン',
#  '特に',
#  '魅力',
#  '的',
#  'ない',
#  '心',
#  '残る',
#  '曲',
#  '少ない',
#  '聞く',
#  'ある',
#  '感じ',
#  'セリフ',
#  '仕草',
#  'わかる',
#  '無理',
#  'くり',
#  '曲',
#  'する',
#  '感',
#  '否める',
#  '中',
#  'アナ',
#  '歌う',
#  '曲',
#  '惑わす',
#  '自分',
#  '道',
#  '的',
#  '感じ',
#  '前作',
#  '国',
#  '他国',
#  '人間',
#  '任せる',
#  '自分勝手',
#  '心',
#  '入れ替える',
#  '歌う',
#  '言い回し',
#  '意味',
#  '不明',
#  '受け取り',
#  '方',
#  'する',
#  'する',
#  '結局',
#  '恋愛',
#  'わかる',
#  '女',
#  '留まる',
#  '成長',
#  '見る',
#  '成長',
#  'いう',
#  '成長',
#  'する',
#  'しっかり',
#  '文字',
#  '学ぶ',
#  '色々',
#  '言葉',
#  '覚える',
#  '人間',
#  '大人',
#  '近づく',
#  '努力',
#  'する',
#  'セリフ',
#  '曲',
#  '伝わる',
#  '喋る',
#  '少し',
#  'う',
#  '最後',
#  '展開',
#  'カタルシス',
#  '的',
#  '展開',
#  '波',
#  '作る',
#  ...]
